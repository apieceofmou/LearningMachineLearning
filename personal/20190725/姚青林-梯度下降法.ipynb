# %%
# sklearn 是我们使用的机器学习库
from sklearn import datasets
# 测试和训练分离
from sklearn.model_selection import train_test_split
# 画图工具
import matplotlib.pyplot as plt 
# 矩阵运算
import numpy as np 
import time
# %matplotlib inline

# make dummy regression data
# features 代表的是特征
X, y = datasets.make_regression(n_samples=250, n_features=1, noise=20, random_state=0, bias=50)
print(X.shape)
print(y.shape)
# 将完整的数据集切割成 训练集和 测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# for theata0, x0 = 1
# 添加1
o_train = np.ones([X_train.shape[0], 1], dtype=X_train.dtype)
o_test = np.ones([X_test.shape[0], 1], dtype=X_test.dtype)
print(o_train.shape)
print(o_test.shape)
# 组合到一起
X_train = np.concatenate((o_train, X_train), axis=1)
X_test = np.concatenate((o_test, X_test), axis=1)
# Out:
# (250, 1)
# (250,)
# (175, 1)
# (75, 1)

# %%
# show data
plt.scatter(X_test[:, 1], y_test, c='red', edgecolors='white')
plt.scatter(X_train[:, 1], y_train, c='orange', edgecolors='white')
plt.ylim((-25, 125))
plt.xlim((-3, 3))
plt.show()

# %%
# 初始化W, 将 W 都初始化成了 0
THETA = np.zeros([2, 1], dtype=np.float32)

# %%
learning_rate = 0.003
step = 100
THETA = np.zeros([2, 1], dtype=np.float32)
print(THETA)
for i in range(step):
  # XTXw - XTy
#   print(np.matmul(X_train.T, X_train))
#   print(np.matmul(np.matmul(X_train.T, X_train), THETA))
#   print(np.matmul(X_train.T, y_train))
  print(X_train.T.shape)
  print(y_train.shape)
  
  grad = np.matmul(np.matmul(X_train.T, X_train), THETA) - np.matmul(X_train.T, y_train).reshape(-1, 1)
  #print(np.dot(np.dot(X_train.T, X_train), THETA))
#   print(grad)
  THETA = THETA - learning_rate * grad
  # (y_hat - y)2
  if i % 20 == 3:
    loss = np.sqrt(np.sum(  (np.dot(X_train, THETA) - y_train) ** 2 ))
    print(loss)
print(THETA)
theta_1 = np.dot(np.dot(np.linalg.inv(np.dot(X_train.T, X_train)), X_train.T), y_train)
print(theta_1)
# Out:
# [[0.]
#  [0.]]
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# 5717.896697919603
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# 5780.923925722323
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# 5780.92393751015
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# 5780.9239375101515
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# 5780.9239375101515
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# (2, 175)
# (175,)
# [[47.72337045]
#  [18.30513929]]
# [47.72337045 18.30513929]
